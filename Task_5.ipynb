# %% [markdown]
# # 1: Social Media – Post Engagement Analyzer

# %%
def engagement(likes):
    
    # Calculating total likes
    Total_likes = 0
    
    for l in likes :
        Total_likes += l
        
    print("Total_likes :" , Total_likes)

    # Deciding whether Total likes comes under Viral post or normal
    
    if Total_likes >= 1000 :
        print('Viral Post')
    else:
        print("Normal Engagement")


# likes at different duration on post during the day

time_period = int(input('enter different time intervals in a day for likes :'))

Likes_list = []

for i in range(time_period):
    Like = int(input("enter likes for the time interval :")) ;
    Likes_list.append(Like)

print("Likes at diffrent time intervals : " , Likes_list)
    
engagement(Likes_list)
# Out:
# enter different time intervals in a day for likes : 3
# enter likes for the time interval : 340
# enter likes for the time interval : 1400
# enter likes for the time interval : 38400
# Likes at diffrent time intervals :  [340, 1400, 38400]
# Total_likes : 40140
# Viral Post

# %% [markdown]
# # 2: Healthcare – Medicine Stock Alert System

# %%
def stock_analyzer(stock):

# Logic to alert sufficient or low stock
    if stock < 10 :
        print("Low Stock Alert")

    else:
        print("Stock Sufficient")

# Input the Stock available
Medicine_stock = int(input("Enter the Stock available of medicine :"))
stock_analyzer(Medicine_stock)
# Out:
# Enter the Stock available of medicine : 9
# Low Stock Alert

# %% [markdown]
# # 3: Agriculture – Rainfall Adequacy Checker

# %%
Required_rainfall_level = 172

def rainfall_analyze(rainfall_data):
    
   
# Calculating toatl and avg rainfall
    
    total_rainfall = 0
    for r in rainfall_data :
        total_rainfall += r

    print("total_rainfall :" , total_rainfall)

    Avg_rainfall = total_rainfall / len(rainfall_data)
    print('Avg_rainfall :' , Avg_rainfall)


# Logic to check for adequate or inadequate rainfall
    
    if  Avg_rainfall >= Required_rainfall_level:
        print('Adequate Rainfall')

    else:
        print('Inadequate Rainfall')
    

# Collecting rainfall data

Rainfall = int(input("Rainfall data for given years :"))
rainfall_data = []

for i in range(Rainfall):
    rain = int(input("Enter the amount of rainfall (cm) :"))
    rainfall_data.append(rain)

print(f'Rainfall data for 4 years : {rainfall_data}')

# Calling function to show final analysis
rainfall_analyze(rainfall_data)
# Out:
# Rainfall data for given years : 4
# Enter the amount of rainfall (cm) : 120
# Enter the amount of rainfall (cm) : 150
# Enter the amount of rainfall (cm) : 135
# Enter the amount of rainfall (cm) : 172
# Rainfall data for 4 years : [120, 150, 135, 172]
# total_rainfall : 577
# Avg_rainfall : 144.25
# Inadequate Rainfall

# %% [markdown]
# # 4: Social Media – Duplicate Account Detection

# %%
# Database to crosscheck if username exists
database  = {'mangu' , 'pradu' , 'vaibhu'}

def username_duplicacy_check():

    while True :

        Username = input("Enter username :").lower()

# Checking if username exists or not 
        if Username in database :
            print()
            print("Flag Account of username :" , Username )
            print('Duplicate Account Found : Yes')
            print()
            
            continue
            
        else:
            print("Account is unique")
            
            break

username_duplicacy_check()
# Out:
# Enter username : Vaibhu
# Flag Account of username : vaibhu
# Duplicate Account Found : Yes
# Enter username : Mangu
# Flag Account of username : mangu
# Duplicate Account Found : Yes
# Enter username : Pradu
# Flag Account of username : pradu
# Duplicate Account Found : Yes
# Enter username : Vishwa
# Account is unique

# %% [markdown]
# # 5: Healthcare – Appointment Eligibility Checker

# %%
def appointment_eligibility(Patient_age):

 # Checking if patient is eligible for appointment
    if Patient_age >= 18 :
        print("Eligible for Appointment")
    else:
        print("Not Eligible for Appointment")

Patient_age = int(input("Enter patient age :"))
appointment_eligibility(Patient_age)
# Out:
# Enter patient age : 19
# Eligible for Appointment

# %% [markdown]
# # 6: Agriculture – Premium Crop Price Filter

# %%
def premium_crops(crops):
 
    # Gives list of premium and regular crops
    Premium_crops = [c for c in crops if c > 2000]
    Regular_crops = [c for c in crops if c < 2000]
    
    print("Premium crops:", Premium_crops)
    print("Regular crops:", Regular_crops)

crops = [1000, 2500, 3200, 500]
premium_crops(crops)
# Out:
# Premium crops: [2500, 3200]
# Regular crops: [1000, 500]

# %% [markdown]
# # 7: System Monitoring – Application Health Checker

# %%
def system_condition(Errors):

# Checks if errors lies in healthy, minor or critical issues
    
    if Errors == 0:
        print("Healthy")
    elif Errors <= 5 :
        print("Minor Issues")
    elif Errors > 5 :
        print("Critical Issues")

Errors = int(input("enter no. of errors received :")) # Input error count
system_condition(Errors)
# Out:
# enter no. of errors received : 15
# Critical Issues

# %% [markdown]
# # 8: Banking – Daily Transaction Limit Checker

# %%
def transaction_limit():
    
    daily_limit = 50000

    while True :
        amount = int(input("Enter amount :"))

    
# Checks if amount entered is less than or equal to dail limit     
        if amount <= daily_limit :
            print("Transaction amount approved")
            daily_limit -= amount          # Updates new limit after transaction

        else :
            print("Transaction rejected")

# Does not allow user to do transaction if limit is consumed 
        if daily_limit == 0 :
            print("Daily Limit consumed")
            break
        
        
        print(f"Limit is : {daily_limit}")


# Calling function
transaction_limit()
# Out:
# Enter amount : 55000
# Transaction rejected
# Limit is : 50000
# Enter amount : 45000
# Transaction amount approved
# Limit is : 5000
# Enter amount : 6000
# Transaction rejected
# Limit is : 5000
# Enter amount : 5000
# Transaction amount approved
# Daily Limit consumed

# %% [markdown]
# # 9: E-Learning – Student Attendance Eligibility System

# %%
def attendence_check(check , name):

    print(f"Student Name : {name}")
# Counting days present  
    
    Attendence = check.count('P')
    print("Present", Attendence , "days out of" , len(check))

# Calculating total attendence in percentage
    
    total_attendence = (Attendence / len(check)) * 100
    print("Attendence Percentage :" , total_attendence , "%")
    
# Determining whethe eligible for exams
    
    if total_attendence > 75 :
        print("Eligible for SPPU exams")
        print("Obedient Student")
    else:
        print("Note Eligible for exam")
        print("Careless Behaviour")

    print()
    
    
Vishwa_attendence = ['P','P','P','A','P','P','A','P','P','P']
Mangesh_attendence = ['P','A','A','A','P','A','A','P','P','A']

attendence_check(Vishwa_attendence , "Vishwa")
attendence_check(Mangesh_attendence , "Mangesh")
# Out:
# Student Name : Vishwa
# Present 8 days out of 10
# Attendence Percentage : 80.0 %
# Eligible for SPPU exams
# Obedient Student
#
# Student Name : Mangesh
# Present 4 days out of 10
# Attendence Percentage : 40.0 %
# Note Eligible for exam
# Careless Behaviour

# %% [markdown]
# # 10: Smart Electricity Bill Analyzer

# %%
def usage(units):


# Calculating Total Bill
    Bill = []

    for i in units :
    
        if 0 <= i <= 100 :
            cost = i * 3
            Bill.append(cost)
    
        elif  101 <= i <= 200 :
            cost = i * 5
            Bill.append(cost)
    
        elif i > 200 :
            cost = i * 7
            Bill.append(cost)

    print(f"Bill for 3 parts of day : {Bill}")

    total_bill = sum(Bill)

    return total_bill
        

# Deciding whether total bill lies under high, moderate, low usage
def Calc_Bill(total_bill) :
    if total_bill < 500 :
        print("Low usage")
    
    elif 500 <= total_bill <= 1500 :
        print("Moderate usage")
    
    elif total_bill > 1500 :
        print("High usage")
        

# Input Units

Duration = int(input("Enter part of day in no. :"))

units = []

for u in range(Duration):
    Units = int(input("Enter Units consumed : "))
    units.append(Units)
    
print(f"Units consumed during 3 parts of day : {units}")
print(f"Total Units Consumed {sum(units)}")

# Calling functions for returning values

Billing_Amount = usage(units)
print('Billing_Amount', Billing_Amount)

Calc_Bill(Calculate_usage)
# Out:
# Enter part of day in no. : 3
# Enter Units consumed :  50
# Enter Units consumed :  150
# Enter Units consumed :  260
# Units consumed during 3 parts of day : [50, 150, 260]
# Total Units Consumed 460
# Bill for 3 parts of day : [150, 750, 1820]
# Billing_Amount 2720
# High usage
